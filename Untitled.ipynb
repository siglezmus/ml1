# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
reg = linear_model.LinearRegression()

reg.fit(df[["area"]], df.price)   #2d array

# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
plt.scatter(df.area, df.price, color="red", marker="+")
plt.plot(df.area, reg.predict(df[["area"]]), color="blue")

# %%
reg.predict([[3300]])

# %%
reg.coef_
# k in kx + b

# %%
reg.intercept_
#b in kx + b

# %%
y = reg.coef_*3300 + reg.intercept_
y
#sample

# %%
reg.predict([[5000]])

# %%
d = pd.read_csv("areas.csv")
d

# %%
p = reg.predict(d)
p

# %%
d["prieces"] = p
d

# %%
d.to_csv("prediction.csv", index =False)

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
rg = linear_model.LinearRegression()
df.columns

rg.fit(df[["year"]], df[["per capita income (US$)"]])

idf = pd.DataFrame(np.arange(2017,2021).reshape(4,1))

idf

odf = pd.DataFrame(rg.predict(idf)) 

odf.to_csv("out_from_framed_array.csv", index = False)

odf
# Out:
#               0
# 0  38803.298869
# 1  39631.763944
# 2  40460.229019
# 3  41288.694094
